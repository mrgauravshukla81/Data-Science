# %%
import numpy as np

# %%
l=[1,2,3,4]

# %%
arr=np.array(l)

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
np.array([[1,2],[3,4]])
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.asarray(l)
# Out:
# array([1, 2, 3, 4])

# %%
np.asanyarray(l)
# Out:
# array([1, 2, 3, 4])

# %%
b=np.matrix(l)

# %%
b
# Out:
# matrix([[1, 2, 3, 4]])

# %%
a=np.array(l)
