# %%
#spread of data
#to measure the spread of data, we can use statistical measures such as range, variance, and standard deviation. Here's a simple Python script that calculates these measures for a given list of numbers:
#two types of variance: population variance and sample variance

# %%
#why we divide by n-1 in sample variance?#When calculating the sample variance, we divide by (n - 1) instead of n to account for 
#we can create a unbaised estimate of the population variance. This adjustment is known as Bessel's correction.

# %%
#why median is better than mean in case of outliers?#The median is less affected by 
# outliers and skewed data because it depends on the middle value(s) rather than 
# the overall distribution.

# %%
import numpy as np

# %%
ages_lst = [22, 25, 30, 35, 40, 45, 50, 55, 60]

# %%
np.mean(ages_lst)
# Out:
# np.float64(40.22222222222222)

# %%
np.var(ages_lst)  #population variance
# Out:
# np.float64(158.17283950617283)

# %%
np.std(ages_lst)  #population standard deviation
# Out:
# np.float64(12.57667839718313)

# %%
import seaborn as sns
sns.histplot(ages_lst, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd

# %%
data=[[10,12,13],[15,18,20],[22,24,25]]
data
df=pd.DataFrame(data,columns=['A','B','C'])

# %%
df.head
# Out:
# <bound method NDFrame.head of     A   B   C
# 0  10  12  13
# 1  15  18  20
# 2  22  24  25>

# %%
df.var()  #sample variance by default
# Out:
# A    36.333333
# B    36.000000
# C    36.333333
# dtype: float64

# %%
df.var(axis=1) #row-wise variance
# Out:
# 0    2.333333
# 1    6.333333
# 2    2.333333
# dtype: float64
